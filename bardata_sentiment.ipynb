# %%
import csv
from textblob import TextBlob
import pandas as pd
import numpy as np
import psycopg2
from nltk.corpus import stopwords
#Cloud database connection (free cloud services by Heroku) (we are using postgreSql)
DATABASE_URL =  'postgres://noxthjmjrdzasn:76ff1ab5fd7f09c73f6fe82ee4a7a2b5fa8920f75f3ef32679a1186ea743f359@ec2-107-21-122-38.compute-1.amazonaws.com:5432/defdshlvvo279k'
conn = psycopg2.connect(DATABASE_URL, sslmode='require')
cursor = conn.cursor()
#reading data from csv file
infile = 'bardata.csv'
bloblist = []
with open(infile, 'r') as csvfile:
    rows = csv.reader(csvfile)
    next(rows)
    #sentiment analysis using TextBlob
    for row in rows:
        rating=row[0]
        sentence = row[1]
        blob = TextBlob(sentence)
        print(blob)
        Polar= blob.sentiment.polarity
        print(Polar)
        subjectivity = blob.sentiment.subjectivity
        if(blob.sentiment.polarity > 0.01):
            blob.sentiment = "positve"
            print(blob.sentiment)
        elif(blob.sentiment.polarity < -0.01):
            blob.sentiment = "negative"
            print(blob.sentiment)
        else:
            blob.sentiment = "neutral"
            print(blob.sentiment)
        bardata = {}
       #tokenizing the text 
        bardata['comment'] = row
        tokens = [t for t in sentence.split()]
        clean_string=""
        
        
        #Removing stops words
        sr= stopwords.words('english')
        clean_tokens = tokens[:]
        for token in tokens:
            if token in stopwords.words('english'):
                clean_tokens.remove(token)
            elif token!="" and token!=" ":
                token=token.replace(',','')
                token=token.replace("'",'')
                token=token.replace('!','')
                token=token.replace('.',' ')
                token=token.replace(':)','')
                token=token.replace(':','')
                if clean_string=="":
                    clean_string=clean_string+token
                else:
                    clean_string=clean_string+","+token
        print(clean_string)
       
        barname='Pray Tell'
        baraddress="838 College Street,Toronto, ON M6H 1A2"
        comment=sentence
        status=blob.sentiment
        image=row[2]
        if image=="":
            image="no image"
        if comment!="":
            cursor.execute("INSERT INTO public.reviews(barname,baraddress,comment,rating, word, status,image) VALUES (%s,%s,%s,%s,%s,%s,%s);", (barname,baraddress,comment,rating,clean_string,status,image))
            print("inserted")
        #commiting chnages to database
        conn.commit()
# Out:
# 0.0
# neutral
# This review is based on my experience last night (Saturday around 7:30pm). We had already eaten so we're just stopping for drinks before a concert down the street at Mod Club. Had no issues getting a table Both my cocktails were delicious and well balanced. They had just released their fall menu. I had a gin based and bourbon based one. Good selection and variety. Service was excellent. Our server was knowledgeable and friendly- gave us just the right amount of attention. Ambience was great - gold and emerald touches and white and plants balancing that. Comfortable booths and chairs. Stools also looked good - which is an important thing to get right. Tip- they had a happy hour until 8pm where your second cocktail was 1/2 price! Also we were told they have a comedy night each Tuesday. The food surrounding tables were getting looked delicious- so I'd love to come back and review that!
# 0.4363617376775272
# positve
# ...

# %%
df.head()
# Out:
#       polar
# 0  0.000000
# 1  0.436362
# 2  0.215530
# 3  0.193003
# 4  0.305952
